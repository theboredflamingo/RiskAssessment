# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#!pip install ta

# %%
#"C:\Users\viole\Downloads\SBIN.csv"
#"C:\Users\viole\Downloads\KOTAKBANK.csv"
ax = pd.read_csv(r"C:\Users\viole\Downloads\SBIN.csv")
ax.head()
# Out:
#          Date Symbol Series  Prev Close    Open    High     Low    Last  \
# 0  2000-01-03   SBIN     EQ      225.60  236.00  243.65  234.25  243.65
# 1  2000-01-04   SBIN     EQ      243.65  243.65  262.00  238.85  258.00
# 2  2000-01-05   SBIN     EQ      259.10  249.00  264.70  245.00  249.05
# 3  2000-01-06   SBIN     EQ      248.45  252.00  268.00  252.00  260.50
# 4  2000-01-07   SBIN     EQ      261.00  261.50  279.90  255.00  279.00
#
#     Close    VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# 0  243.65  240.83  2373228  5.715338e+13     NaN                 NaN
# 1  259.10  251.46  4495741  1.130506e+14     NaN                 NaN
# 2  248.45  252.35  3434058  8.666008e+13     NaN                 NaN
# 3  261.00  262.18  6658801  1.745817e+14     NaN                 NaN
# 4  273.30  269.02  7873985  2.118287e+14     NaN                 NaN
#
#    %Deliverble
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
hd = pd.read_csv(r"C:\Users\viole\Downloads\KOTAKBANK.csv")
hd.head()
# Out:
#          Date    Symbol Series  Prev Close   Open    High     Low    Last  \
# 0  2000-01-03  KOTAKMAH     EQ      212.35  220.0  229.35  220.00  229.35
# 1  2000-01-04  KOTAKMAH     EQ      229.35  247.7  247.70  225.25  247.70
# 2  2000-01-05  KOTAKMAH     EQ      246.95  229.0  240.00  227.20  228.00
# 3  2000-01-06  KOTAKMAH     EQ      228.40  235.1  239.00  217.00  224.95
# 4  2000-01-07  KOTAKMAH     EQ      225.90  213.0  219.00  207.85  207.85
#
#     Close    VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# 0  229.35  229.13    7086  1.623640e+11     NaN                 NaN
# 1  246.95  244.12   73681  1.798729e+12     NaN                 NaN
# 2  228.40  233.75  105799  2.473093e+12     NaN                 NaN
# 3  225.90  226.84   40202  9.119546e+11     NaN                 NaN
# 4  208.85  209.94   24463  5.135747e+11     NaN                 NaN
#
#    %Deliverble
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
from datetime import datetime
def get_dates(date_string):
    date_object = datetime.strptime(date_string, "%Y-%m-%d")
    return date_object

# %%
ax.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5306 non-null   object
#  1   Symbol              5306 non-null   object
#  2   Series              5306 non-null   object
#  3   Prev Close          5306 non-null   float64
#  4   Open                5306 non-null   float64
#  5   High                5306 non-null   float64
#  6   Low                 5306 non-null   float64
#  7   Last                5306 non-null   float64
#  8   Close               5306 non-null   float64
#  9   VWAP                5306 non-null   float64
#  10  Volume              5306 non-null   int64
#  11  Turnover            5306 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4792 non-null   float64
#  14  %Deliverble         4792 non-null   float64
# ...

# %%
ax.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  5306.000000  5306.000000  5306.000000  5306.000000  5306.000000
# mean    965.871438   967.182115   982.101583   950.898587   965.727026
# std     857.785547   858.925475   870.739801   845.761231   857.510230
# min     141.450000   142.850000   147.950000   140.050000   140.550000
# 25%     258.662500   259.262500   262.662500   255.000000   258.500000
# 50%     475.275000   475.050000   482.625000   466.400000   475.000000
# 75%    1722.025000  1725.000000  1755.000000  1695.000000  1718.737500
# max    3489.950000  3505.000000  3515.000000  3451.350000  3499.000000
#
#              Close        VWAP        Volume      Turnover        Trades  \
# count  5306.000000  5306.00000  5.306000e+03  5.306000e+03  2.456000e+03
# mean    965.895543   966.77033  1.003930e+07  4.136854e+14  1.507028e+05
# std     857.766537   858.38307  1.783189e+07  4.578376e+14  1.082755e+05
# ...

# %%
hd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4985 entries, 0 to 4984
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                4985 non-null   object
#  1   Symbol              4985 non-null   object
#  2   Series              4985 non-null   object
#  3   Prev Close          4985 non-null   float64
#  4   Open                4985 non-null   float64
#  5   High                4985 non-null   float64
#  6   Low                 4985 non-null   float64
#  7   Last                4985 non-null   float64
#  8   Close               4985 non-null   float64
#  9   VWAP                4985 non-null   float64
#  10  Volume              4985 non-null   int64
#  11  Turnover            4985 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4789 non-null   float64
#  14  %Deliverble         4789 non-null   float64
# ...

# %%
hd.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  4985.000000  4985.000000  4985.000000  4985.000000  4985.000000
# mean    696.291755   697.154925   708.147543   684.984112   696.556409
# std     440.761023   441.037354   445.558375   435.579256   440.924524
# min      27.300000    26.950000    30.000000    26.000000    26.500000
# 25%     355.150000   355.000000   366.900000   346.650000   356.000000
# 50%     650.950000   652.650000   662.000000   638.450000   650.500000
# 75%     966.400000   967.000000   979.600000   955.250000   968.000000
# max    2019.650000  2016.700000  2049.000000  1999.000000  2023.900000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  4985.000000  4985.000000  4.985000e+03  4.985000e+03    2456.000000
# mean    696.615135   696.772050  1.283626e+06  1.355506e+14   54912.741857
# std     440.938692   440.580761  2.486726e+06  3.589591e+14   60401.337897
# ...

# %%
ax['Date'] = ax['Date'].apply(get_dates)
hd['Date'] = hd['Date'].apply(get_dates)

# %%
ax['year'] = ax['Date'].dt.year
ax['month'] = ax['Date'].dt.month
ax['day'] = ax['Date'].dt.day
hd['year'] = hd['Date'].dt.year
hd['month'] = hd['Date'].dt.month
hd['day'] = hd['Date'].dt.day

# %%
axis = ax[(ax['year'] >= 2015) & (ax['year'] < 2022)]
hdfc  = hd[(hd['year'] >= 2015) & (hd['year'] < 2022)]

# %%
#axis only, repeat for hdfc
from ta.trend import SMAIndicator, MACD
from ta.momentum import RSIIndicator

#simple moving average, moving average convergence divergence, relative strength index, 
axis['SMA_50'] = SMAIndicator(close=axis['Close'], window=50).sma_indicator()
axis['SMA_200'] = SMAIndicator(close=axis['Close'], window=200).sma_indicator()
axis['RSI'] = RSIIndicator(close=axis['Close']).rsi()
macd = MACD(close=axis['Close'])
axis['SMA_50'].fillna(0, inplace=True)
axis['SMA_200'].fillna(0, inplace=True)
axis['RSI'].fillna(0, inplace=True)
# Out:
# C:\Users\viole\AppData\Local\Temp\ipykernel_14060\3372530721.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   axis['SMA_50'] = SMAIndicator(close=axis['Close'], window=50).sma_indicator()
# C:\Users\viole\AppData\Local\Temp\ipykernel_14060\3372530721.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   axis['SMA_200'] = SMAIndicator(close=axis['Close'], window=200).sma_indicator()
# C:\Users\viole\AppData\Local\Temp\ipykernel_14060\3372530721.py:7: SettingWithCopyWarning:
# ...

# %%
axis.head()
# Out:
#            Date Symbol Series  Prev Close    Open    High     Low   Last  \
# 3740 2015-01-01   SBIN     EQ      311.85  312.45  315.00  310.70  314.0
# 3741 2015-01-02   SBIN     EQ      314.00  314.35  318.30  314.35  315.6
# 3742 2015-01-05   SBIN     EQ      315.25  316.25  316.80  312.10  312.8
# 3743 2015-01-06   SBIN     EQ      312.75  310.00  311.10  298.70  299.9
# 3744 2015-01-07   SBIN     EQ      299.90  300.00  302.55  295.15  301.4
#
#        Close    VWAP  ...      Turnover    Trades  Deliverable Volume  \
# 3740  314.00  313.67  ...  1.925489e+14   58688.0           1877677.0
# 3741  315.25  316.80  ...  3.147389e+14   79553.0           4221685.0
# 3742  312.75  313.84  ...  2.867432e+14   88236.0           3845173.0
# 3743  299.90  305.14  ...  4.677601e+14  169268.0           7424847.0
# 3744  300.15  299.95  ...  4.513243e+14  147185.0           5631400.0
#
#       %Deliverble  year  month  day  SMA_50  SMA_200  RSI
# ...

# %%
hdfc['SMA_50'] = SMAIndicator(close=hdfc['Close'], window=50).sma_indicator()
hdfc['SMA_200'] = SMAIndicator(close=hdfc['Close'], window=200).sma_indicator()
hdfc['RSI'] = RSIIndicator(close=hdfc['Close']).rsi()
macd = MACD(close=hdfc['Close'])
hdfc['SMA_50'].fillna(0, inplace=True)
hdfc['SMA_200'].fillna(0, inplace=True)
hdfc['RSI'].fillna(0, inplace=True)
# Out:
# C:\Users\viole\AppData\Local\Temp\ipykernel_14060\868320399.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hdfc['SMA_50'] = SMAIndicator(close=hdfc['Close'], window=50).sma_indicator()
# C:\Users\viole\AppData\Local\Temp\ipykernel_14060\868320399.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hdfc['SMA_200'] = SMAIndicator(close=hdfc['Close'], window=200).sma_indicator()
# C:\Users\viole\AppData\Local\Temp\ipykernel_14060\868320399.py:3: SettingWithCopyWarning:
# ...

# %%
hdfc.head()
# Out:
#            Date     Symbol Series  Prev Close    Open     High      Low  \
# 3419 2015-01-01  KOTAKBANK     EQ     1263.90  1263.8  1265.00  1251.10
# 3420 2015-01-02  KOTAKBANK     EQ     1258.60  1261.0  1279.00  1258.30
# 3421 2015-01-05  KOTAKBANK     EQ     1271.55  1272.1  1278.85  1262.00
# 3422 2015-01-06  KOTAKBANK     EQ     1266.45  1255.0  1262.25  1233.55
# 3423 2015-01-07  KOTAKBANK     EQ     1251.35  1247.5  1303.95  1247.50
#
#          Last    Close     VWAP  ...      Turnover   Trades  \
# 3419  1261.75  1258.60  1259.52  ...  3.161377e+13   9230.0
# 3420  1278.00  1271.55  1271.97  ...  8.036522e+13  25080.0
# 3421  1267.60  1266.45  1266.77  ...  3.865100e+13  15419.0
# 3422  1253.00  1251.35  1251.25  ...  1.419603e+14  45554.0
# 3423  1272.90  1271.50  1280.55  ...  2.286922e+14  29405.0
#
#       Deliverable Volume  %Deliverble  year  month  day  SMA_50  SMA_200  RSI
# 3419            118205.0       0.4709  2015      1    1     0.0      0.0  0.0
# ...

# %%
axis.drop('Symbol', axis=1)
hdfc.drop('Symbol', axis=1)
axis.head()
# Out:
#            Date Symbol Series  Prev Close    Open    High     Low   Last  \
# 3740 2015-01-01   SBIN     EQ      311.85  312.45  315.00  310.70  314.0
# 3741 2015-01-02   SBIN     EQ      314.00  314.35  318.30  314.35  315.6
# 3742 2015-01-05   SBIN     EQ      315.25  316.25  316.80  312.10  312.8
# 3743 2015-01-06   SBIN     EQ      312.75  310.00  311.10  298.70  299.9
# 3744 2015-01-07   SBIN     EQ      299.90  300.00  302.55  295.15  301.4
#
#        Close    VWAP  ...      Turnover    Trades  Deliverable Volume  \
# 3740  314.00  313.67  ...  1.925489e+14   58688.0           1877677.0
# 3741  315.25  316.80  ...  3.147389e+14   79553.0           4221685.0
# 3742  312.75  313.84  ...  2.867432e+14   88236.0           3845173.0
# 3743  299.90  305.14  ...  4.677601e+14  169268.0           7424847.0
# 3744  300.15  299.95  ...  4.513243e+14  147185.0           5631400.0
#
#       %Deliverble  year  month  day  SMA_50  SMA_200  RSI
# ...

# %%
hdfc.head()
# Out:
#            Date     Symbol Series  Prev Close    Open     High      Low  \
# 3419 2015-01-01  KOTAKBANK     EQ     1263.90  1263.8  1265.00  1251.10
# 3420 2015-01-02  KOTAKBANK     EQ     1258.60  1261.0  1279.00  1258.30
# 3421 2015-01-05  KOTAKBANK     EQ     1271.55  1272.1  1278.85  1262.00
# 3422 2015-01-06  KOTAKBANK     EQ     1266.45  1255.0  1262.25  1233.55
# 3423 2015-01-07  KOTAKBANK     EQ     1251.35  1247.5  1303.95  1247.50
#
#          Last    Close     VWAP  ...      Turnover   Trades  \
# 3419  1261.75  1258.60  1259.52  ...  3.161377e+13   9230.0
# 3420  1278.00  1271.55  1271.97  ...  8.036522e+13  25080.0
# 3421  1267.60  1266.45  1266.77  ...  3.865100e+13  15419.0
# 3422  1253.00  1251.35  1251.25  ...  1.419603e+14  45554.0
# 3423  1272.90  1271.50  1280.55  ...  2.286922e+14  29405.0
#
#       Deliverable Volume  %Deliverble  year  month  day  SMA_50  SMA_200  RSI
# 3419            118205.0       0.4709  2015      1    1     0.0      0.0  0.0
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
axis['Date'] = pd.to_datetime(axis['Date'])
axis.set_index('Date', inplace=True)

# Select relevant columns for forecasting
axisLSTM = axis[['Open', 'High', 'Low', 'Close', 'Volume', 'SMA_50', 'SMA_200', 'RSI', 'Prev Close']]
# Out:
# C:\Users\viole\AppData\Local\Temp\ipykernel_14060\1789657288.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   axis['Date'] = pd.to_datetime(axis['Date'])

# %%
scalers = {}
for column in axisLSTM.columns:
    scalers[column] = MinMaxScaler(feature_range=(0, 1))
    axisLSTM[column] = scalers[column].fit_transform(axisLSTM[[column]])
# Out:
# C:\Users\viole\AppData\Local\Temp\ipykernel_14060\384013182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   axisLSTM[column] = scalers[column].fit_transform(axisLSTM[[column]])
# C:\Users\viole\AppData\Local\Temp\ipykernel_14060\384013182.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   axisLSTM[column] = scalers[column].fit_transform(axisLSTM[[column]])
# C:\Users\viole\AppData\Local\Temp\ipykernel_14060\384013182.py:4: SettingWithCopyWarning:
# ...

# %%
train_size = int(len(axisLSTM) * 0.8)
train_data, test_data = axisLSTM[:train_size], axisLSTM[train_size:]

# %%
def create_dataset(dataset, time_step=1):
    X, Y = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step)].values
        X.append(a)
        Y.append(dataset.iloc[i + time_step, 3])  # 'Close' is the target variable at index 3
    return np.array(X), np.array(Y)

time_step = 50
X_train, Y_train = create_dataset(train_data, time_step)
X_test, Y_test = create_dataset(test_data, time_step)

# Reshape input to be [samples, time steps, features] which is required for LSTM
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2])
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
model = Sequential()
model.add(Input(shape=(time_step, X_train.shape[2])))
model.add(LSTM(50, return_sequences=True))
model.add(Dropout(0.2))  # Dropout layer to prevent overfitting
model.add(LSTM(50, return_sequences=False))
model.add(Dropout(0.2))  # Dropout layer to prevent overfitting
model.add(Dense(25))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')
model
# Out:
# <Sequential name=sequential, built=True>

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
model.fit(X_train, Y_train, batch_size=1, epochs=15, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/15
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 36s 31ms/step - loss: 0.0089 - val_loss: 0.0128
# Epoch 2/15
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 29s 30ms/step - loss: 0.0032 - val_loss: 0.0020
# Epoch 3/15
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 29s 30ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 4/15
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 38s 39ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 5/15
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 43s 41ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 6/15
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 41s 41ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 7/15
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 38s 38ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 8/15
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 41s 38ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 9/15
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 42s 39ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 10/15
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 42s 39ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 11/15
# ...

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %%
train_predict = scalers['Close'].inverse_transform(train_predict)
test_predict = scalers['Close'].inverse_transform(test_predict)

# Invert the scaling for the actual values
Y_train = scalers['Close'].inverse_transform([Y_train])
Y_test = scalers['Close'].inverse_transform([Y_test])

# %%
train_plot = np.empty_like(axisLSTM['Close'])
train_plot[:] = np.nan
train_plot[time_step:len(train_predict) + time_step] = train_predict.flatten()

test_plot = np.empty_like(axisLSTM['Close'])
test_plot[:] = np.nan
test_plot[len(train_predict) + (time_step * 2) + 1:len(axisLSTM) - 1] = test_predict.flatten()

plt.figure(figsize=(12, 6))
plt.plot(axis['Close'], label='Original Data')
plt.plot(pd.DataFrame(train_plot, index=axisLSTM.index), label='Training Predictions')
plt.plot(pd.DataFrame(test_plot, index=axisLSTM.index), label='Testing Predictions')
plt.xlabel('Date')
plt.ylabel('Market Movements')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

# Calculate metrics for training data
train_mse = mean_squared_error(Y_train.flatten(), train_predict.flatten())
train_rmse = math.sqrt(train_mse)
train_mae = mean_absolute_error(Y_train.flatten(), train_predict.flatten())

# Calculate metrics for testing data
test_mse = mean_squared_error(Y_test.flatten(), test_predict.flatten())
test_rmse = math.sqrt(test_mse)
test_mae = mean_absolute_error(Y_test.flatten(), test_predict.flatten())

print('Training MSE: ', train_mse)
print('Training RMSE: ', train_rmse)
print('Training MAE: ', train_mae)

print('Testing MSE: ', test_mse)
print('Testing RMSE: ', test_rmse)
print('Testing MAE: ', test_mae)
# Out:
# Training MSE:  52.505147080863125
# Training RMSE:  7.246043546713139
# Training MAE:  5.367022672044944
# Testing MSE:  132.2285736306351
# Testing RMSE:  11.499068380987875
# Testing MAE:  8.770333792682838

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import datetime

# Define the stock ticker and download data
ticker = 'AXISBANK.NS'
end_date = datetime.datetime.now()
start_date = end_date - datetime.timedelta(days=365)
data = yf.download(ticker, start=start_date, end=end_date)

# Preprocessing
data['Date'] = data.index
data.reset_index(drop=True, inplace=True)

# Use only the 'Close' column
data_close = data[['Date', 'Close']]

# Create features (previous day's close price) and target (next day's close price)
data_close['Previous_Close'] = data_close['Close'].shift(1)
data_close = data_close.dropna()

# Split data into features and target
X = data_close[['Previous_Close']].values
y = data_close['Close'].values

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
X_scaled = scaler.fit_transform(X)
y_scaled = scaler.fit_transform(y.reshape(-1, 1))

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, shuffle=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\viole\AppData\Local\Temp\ipykernel_14060\3855230404.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_close['Previous_Close'] = data_close['Close'].shift(1)

# %%
model2 = LinearRegression()
model2.fit(X_train, y_train)

# Predicting on test data
y_train_pred = model2.predict(X_train)
y_test_pred = model2.predict(X_test)

# Transform back to original scale
y_train_pred = scaler.inverse_transform(y_train_pred)
y_test_pred = scaler.inverse_transform(y_test_pred)
y_train_actual = scaler.inverse_transform(y_train)
y_test_actual = scaler.inverse_transform(y_test)

# %%
# Forecast future prices (next 30 days)
future_days = 30

# Generate future dates
future_dates = pd.date_range(start=data_close['Date'].iloc[-1], periods=future_days + 1)

# Forecasting future prices
future_predictions = []

last_value = X_test[-1]
print(last_value)
for _ in range(future_days):
    next_pred = model2.predict(last_value.reshape(1, -1))
    future_predictions.append(next_pred[0])
    last_value = np.append(last_value[1:], next_pred)

# Inverse transform to get actual prices
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))

# Ensure future_predictions has the same length as future_dates
if len(future_predictions) != len(future_dates):
    future_dates = future_dates[:len(future_predictions)]

# Prepare dates for plotting
train_dates = data_close['Date'].iloc[:len(y_train)].values
test_dates = data_close['Date'].iloc[len(y_train):len(y_train) + len(y_test)].values

# Plotting
plt.figure(figsize=(14, 8))
plt.plot(data_close['Date'], data_close['Close'], label='Actual Price')
#plt.plot(train_dates, y_train_pred, label='Train Predictions')
plt.plot(test_dates, y_test_pred, label='Test Predictions')
plt.plot(future_dates, future_predictions, label='Future Predictions')

plt.title('Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()
# Out:
# [0.97944041]

# %%
import yfinance as yf
import pandas as pd

# Download historical price data for a stock and market index
stock_ticker = 'AXISBANK.NS'
market_ticker = 'NSE'  # S&P 500

stock_data = yf.download(stock_ticker, start='2020-01-01', end='2023-01-01')
market_data = yf.download(market_ticker, start='2020-01-01', end='2023-01-01')

# Calculate daily returns
stock_data['Returns'] = stock_data['Adj Close'].pct_change()
market_data['Returns'] = market_data['Adj Close'].pct_change()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
import numpy as np
#volatility across a year
volatility = stock_data['Returns'].std() * np.sqrt(252)  # Annualized volatility
print(f"Annualized Volatility: {volatility:.2%}")
# Out:
# Annualized Volatility: 43.69%

# %%
import statsmodels.api as sm

# Drop NaN values and align data
returns = pd.concat([stock_data['Returns'], market_data['Returns']], axis=1).dropna()
returns.columns = ['Stock', 'Market']
#closer to 1 indicates the similarity to market movements
# Perform linear regression
X = sm.add_constant(returns['Market'])
model = sm.OLS(returns['Stock'], X).fit()
beta = model.params[1]
print(f"Beta: {beta:.2f}")
# Out:
# Beta: 0.07

# %%
stock_data['Avg Daily Volume'] = stock_data['Volume'].mean()
#higher, is better
# Print average daily volume
print(f"Average Daily Trading Volume for {stock_ticker}:", stock_data['Avg Daily Volume'].iloc[0])
# Out:
# Average Daily Trading Volume for AXISBANK.NS: 16619144.120481927

# %%
# Calculate standard deviation of daily returns (volatility)
stock_daily_volatility = stock_data['Returns'].std()
print(f"Standard Deviation of Daily Returns ({stock_ticker}):", stock_daily_volatility)
#daily value
# Out:
# Standard Deviation of Daily Returns (AXISBANK.NS): 0.02752247887340525

# %%
    from sklearn.preprocessing import StandardScaler
    START = "2015-01-01"
    TODAY = datetime.date.today().strftime("%Y-%m-%d")
    
    # Download stock data
    data = yf.download("AXISBANK.NS", START, TODAY)
    
    # Prepare the data
    df_train = data[['Close']].copy()
    df_train.reset_index(inplace=True)
    df_train['Date'] = pd.to_datetime(df_train['Date'])
    df_train['Date_ordinal'] = df_train['Date'].map(pd.Timestamp.toordinal)

    if len(df_train) == 0:
        st.error('No valid data available for the selected stock. Please choose another stock or check your custom ticker.')
    else:
        X = df_train[['Date_ordinal']]
        y = df_train['Close']

        # Scaling the data
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)

        # Fit the model
        model = LinearRegression()
        model.fit(X_scaled, y)

        # Predict the next day
        next_day = (pd.to_datetime(TODAY) + datetime.timedelta(days=1)).to_pydatetime()
        next_day_ordinal = np.array([[next_day.toordinal()]])
        next_day_scaled = scaler.transform(next_day_ordinal)

        # Make prediction
        next_day_prediction = model.predict(next_day_scaled)

        # Create a DataFrame for the forecast
        forecast = pd.DataFrame({'Date': [next_day], 'Predicted Close': next_day_prediction})
# Out:
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\viole\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
forecast
# Out:
#         Date  Predicted Close
# 0 2024-07-21       942.436278

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error
from math import sqrt
import datetime

def forecast(ticker):
    # Set dates for data download
    TODAY = datetime.datetime.today().date()
    Y1 = TODAY - datetime.timedelta(days=365)

    # Download data
    data = yf.download(ticker, start=Y1, end=TODAY)
    
    # Prepare data
    data['Previous_Close'] = data['Close'].shift(1)
    data = data.dropna()
    
    X = data[['Previous_Close']].values
    y = data['Close'].values
    
    # Scale data
    scaler = MinMaxScaler(feature_range=(0, 1))
    X_scaled = scaler.fit_transform(X)
    y_scaled = scaler.fit_transform(y.reshape(-1, 1))
    
    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, shuffle=False)
    
    # Train model
    model = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=0.1)
    model.fit(X_train, y_train.ravel())
    
    # Predict using the test set
    y_pred = model.predict(X_test)
    
    # Inverse transform predictions and actual values to original scale
    y_test_inverse = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()
    y_pred_inverse = scaler.inverse_transform(y_pred.reshape(-1, 1)).flatten()
    
    # Calculate MAE, MSE, and RMSE
    mae = mean_absolute_error(y_test_inverse, y_pred_inverse)
    mse = mean_squared_error(y_test_inverse, y_pred_inverse)
    rmse = sqrt(mse)
    
    # Print errors
    print("Mean Absolute Error (MAE):", mae)
    print("Mean Squared Error (MSE):", mse)
    print("Root Mean Squared Error (RMSE):", rmse)

# Example usage
forecast('AXISBANK.NS')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Mean Absolute Error (MAE): 16.288673946875544
# Mean Squared Error (MSE): 596.4371242659034
# Root Mean Squared Error (RMSE): 24.422062244329478

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
import datetime
from math import sqrt

def predict(ticker):
    START = "2015-01-01"
    TODAY = datetime.date.today().strftime("%Y-%m-%d")
    
    # Download stock data
    data = yf.download(ticker, START, TODAY)
    
    # Prepare the data
    df_train = data[['Close']].copy()
    df_train.reset_index(inplace=True)
    df_train['Date'] = pd.to_datetime(df_train['Date'])
    df_train['Date_ordinal'] = df_train['Date'].map(pd.Timestamp.toordinal)

    if len(df_train) == 0:
        print('No valid data available for the selected stock. Please choose another stock or check your custom ticker.')
    else:
        X = df_train[['Date_ordinal']]
        y = df_train['Close']

        # Scaling the data
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)

        # Fit the model
        model = LinearRegression()
        model.fit(X_scaled, y)

        # Predict using the same dataset to calculate errors
        y_pred = model.predict(X_scaled)

        # Calculate MAE, MSE, and RMSE
        mae = mean_absolute_error(y, y_pred)
        mse = mean_squared_error(y, y_pred)
        rmse = sqrt(mse)
        
        # Print errors
        print("Mean Absolute Error (MAE):", mae)
        print("Mean Squared Error (MSE):", mse)
        print("Root Mean Squared Error (RMSE):", rmse)

# Example usage
predict('AXISBANK.NS')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Mean Absolute Error (MAE): 87.27825813110964
# Mean Squared Error (MSE): 14009.320998210851
# Root Mean Squared Error (RMSE): 118.36097751459664
